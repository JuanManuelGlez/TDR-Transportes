# %%
import pandas as pd

# %%
#Creamos un dataframe por cada uno de los archivos
df = pd.read_excel('MisViajes_01012024_02012024.xlsx')
df2 = pd.read_excel('MisViajes_03012024_04012024.xlsx')
df3 = pd.read_excel('MisViajes_05012024_06012024.xlsx')
df4 = pd.read_excel('MisViajes_07012024_08012024.xlsx')
df5 = pd.read_excel('MisViajes_09012024_10012024.xlsx')
df6 = pd.read_excel('MisViajes_11012024_12012024.xlsx')
df7 = pd.read_excel('MisViajes_13012024_14012024.xlsx')
df8 = pd.read_excel('MisViajes_15012024_16012024.xlsx')
df9 = pd.read_excel('MisViajes_17012024_18012024.xlsx')
df10 = pd.read_excel('MisViajes_19012024_20012024.xlsx')
df11 = pd.read_excel('MisViajes_21012024_22012024.xlsx')
df12 = pd.read_excel('MisViajes_23012024_24012024.xlsx')
df13 = pd.read_excel('MisViajes_25012024_26012024.xlsx')
df14 = pd.read_excel('MisViajes_27012024_28012024.xlsx')
df15 = pd.read_excel('MisViajes_29012024_30012024.xlsx')
df16 = pd.read_excel('MisViajes_31012024_31012024.xlsx')

df16.head()
# Out:
#   Concesionaria          Fecha Viaje           Tag  \
# 0       CEPSICE  31/01/2024 23:55:54  OHLM02010089
# 1       VIAPASS  31/01/2024 23:47:34  OHLM01632724
# 2          PASE  31/01/2024 23:46:38  OHLM02010116
# 3          PASE  31/01/2024 23:46:17  OHLM01644821
# 4          PASE  31/01/2024 23:45:00  OHLM01386314
#
#                                            Entrada  \
# 0                                MEXICO-CUERNAVACA
# 1  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B
# 2                       VISTA HERMOSA - LA BARCA 8
# 3                       VISTA HERMOSA - LA BARCA 8
# 4        ENT.LOMA DE CABALLO - ENT.FRONTERA CSTA 1
#
#                                             Salida  Importe
# 0                                MEXICO-CUERNAVACA    427.0
# 1  TUXTLA GUTIERREZ -SN CRISTOBAL DE LAS CASAS 08B    265.0
# 2                       VISTA HERMOSA - LA BARCA 8     78.0
# 3                       VISTA HERMOSA - LA BARCA 8    117.0
# ...

# %%
# Concatenamos los dataframes
df = pd.concat([df, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16])

# Mostramos el dataframe concatenado
df.head()

# Guardamos el dataframe concatenado en un archivo excel
df.to_excel('TeleviaEnero.xlsx', index=False)
